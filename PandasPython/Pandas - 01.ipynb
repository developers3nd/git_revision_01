# %%
#data = [ "ahmed" , "owais"]

#print(data)

# for x in data:
#     print(x)
# Out:
# ['ahmed', 'owais']
# ahmed
# owais

# %%
#pandas 
from pandas import Series
e = Series(["jawaid", "owais"])
print(e)
# Out:
# 0    jawaid
# 1     owais
# dtype: object

# %%
from pandas import Series
e = Series(["jawaid", "owais"])

e[1]

print[e[1])
# Out:
# owais

# %%
from pandas import Series

student = {"Name" : "Jawaid", "Age" : 45 , "Fee" : 450.64 }
list = Series(student)
list
# Out:
# Name    Jawaid
# Age         45
# Fee     450.64
# dtype: object

# %%
from pandas import Series

student = {"Name" : "Jawaid", "Age" : 45}
list = Series(student)
list["Name"]
print(list["Name"])
# Out:
# Jawaid

# %%
from pandas import Series

s = Series([3,4,5], index=['x','y','z'])
print(s)
print(s['z'])
# Out:
# x    3
# y    4
# z    5
# dtype: int64
# 5

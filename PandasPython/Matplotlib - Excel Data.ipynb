# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style

# style.use('ggplot')

data = pd.read_excel(r'C:\Users\DevLaptop\Desktop\PandasPython\data.xlsx')

# print(data)

x = list(data['Items'])
y = list(data['Qty'])

# print(x, " ---- " , y)

plt.figure(figsize=(10,10))
plt.scatter(x,y,edgecolors="green",c="blue")
plt.title("Excel Stock Sheet")
plt.show()

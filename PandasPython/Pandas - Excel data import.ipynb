# %%
import pandas as pd


data = pd.read_excel(r'C:\Users\DevLaptop\Desktop\PandasPython\data.xlsx')

#data
# print(data)
# data.head(2)
#data.tail(2)


#data frame ( columns fetch )
df = pd.DataFrame(data,columns=['Items','Qty','Unit'])
df
# Out:
#         Items  Qty  Unit
# 0       Mouse   20   250
# 1      Tablet   30  5000
# 2  Data Cable   50   120
